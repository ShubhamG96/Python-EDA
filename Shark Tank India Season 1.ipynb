# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Shark_Tank_India_S1.csv")

# %%
data.head(3)
# Out:
#    episode_number  startup_number           brand_name  \
# 0               1               1  BluePine Industries
# 1               1               2        Booz scooters
# 2               1               3  Heart up my Sleeves
#
#                                      description  deal_offered  \
# 0                                   Frozen Momos             1
# 1  Renting e-bike for mobility in private spaces             1
# 2                             Detachable Sleeves             1
#
#    startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 0                      50.0                     5.0                1000.00
# 1                      40.0                    15.0                 266.67
# 2                      25.0                    10.0                 250.00
#
#    deal_amount_lakhs  deal_equity  ...  ghazal_invested  namita_present  \
# 0               75.0         16.0  ...                0               1
# ...

# %%
data.tail(3)
# Out:
#      episode_number  startup_number      brand_name           description  \
# 118              36             119    French Crown     Clothing Industry
# 119              36             120  Store My Goods     Storage solutions
# 120              36             121        Devnagri  Translation platform
#
#      deal_offered  startup_ask_amount_lakhs  startup_ask_percentage  \
# 118             0                     150.0                    0.33
# 119             1                     100.0                    1.75
# 120             0                     100.0                    1.00
#
#      startup_ask_valuation  deal_amount_lakhs  deal_equity  ...  \
# 118                45000.0                0.0          0.0  ...
# 119                 5714.0              100.0          4.0  ...
# 120                10000.0                0.0          0.0  ...
#
#      ghazal_invested  namita_present  namita_invested  peyush_present  \
# ...

# %%
data.shape
# Out:
# (121, 32)

# %%
data.columns
# Out:
# Index(['episode_number', 'startup_number', 'brand_name', 'description',
#        'deal_offered', 'startup_ask_amount_lakhs', 'startup_ask_percentage',
#        'startup_ask_valuation', 'deal_amount_lakhs', 'deal_equity',
#        'deal_valuation', 'loan_element_present', 'loan_amount',
#        'rannvijay_present', 'abish_present', 'aman_present', 'aman_invested',
#        'anupam_present', 'anupam_invested', 'ashneer_present',
#        'ashneer_invested', 'ghazal_present', 'ghazal_invested',
#        'namita_present', 'namita_invested', 'peyush_present',
#        'peyush_invested', 'vineeta_present', 'vineeta_invested',
#        'sharks_offering', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
#Droping Unwanted Columns
data.drop(['episode_number','abish_present','aman_present','anupam_present','rannvijay_present',
          'ashneer_present','ghazal_present','namita_present','peyush_present','vineeta_present'] ,axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   startup_number            121 non-null    int64
#  1   brand_name                121 non-null    object
#  2   description               121 non-null    object
#  3   deal_offered              121 non-null    int64
#  4   startup_ask_amount_lakhs  121 non-null    float64
#  5   startup_ask_percentage    121 non-null    float64
#  6   startup_ask_valuation     121 non-null    float64
#  7   deal_amount_lakhs         121 non-null    float64
#  8   deal_equity               121 non-null    float64
#  9   deal_valuation            121 non-null    float64
#  10  loan_element_present      121 non-null    int64
#  11  loan_amount               121 non-null    int64
#  12  aman_invested             121 non-null    int64
# ...

# %%
data.describe().T.style.background_gradient(cmap='hot')
# Out:
# <style type="text/css">
# ...

# %%
data.isnull().sum()
# Out:
# startup_number              0
# brand_name                  0
# description                 0
# deal_offered                0
# startup_ask_amount_lakhs    0
# startup_ask_percentage      0
# startup_ask_valuation       0
# deal_amount_lakhs           0
# deal_equity                 0
# deal_valuation              0
# loan_element_present        0
# loan_amount                 0
# aman_invested               0
# anupam_invested             0
# ashneer_invested            0
# ghazal_invested             0
# namita_invested             0
# peyush_invested             0
# vineeta_invested            0
# sharks_offering             0
# amount_per_shark            0
# equity_per_shark            0
# dtype: int64

# %% [markdown]
# # Data Analysis

# %% [markdown]
# #Startup Ask Amount : Min & Max

# %%
data[data["startup_ask_amount_lakhs"]==data["startup_ask_amount_lakhs"].max()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#     brand_name      description  deal_offered  startup_ask_percentage  \
# 30  Gopal's 56  Fiber Ice Cream             0                    25.0
#
#     deal_amount_lakhs  deal_equity  deal_valuation  amount_per_shark  \
# 30                0.0          0.0             0.0               0.0
#
#     equity_per_shark
# 30               0.0

# %%
data[data["startup_ask_amount_lakhs"]==data["startup_ask_amount_lakhs"].min()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#             brand_name          description  deal_offered  \
# 85  Watt Technovations  Ventilated PPE Kits             1
#
#     startup_ask_percentage  deal_amount_lakhs  deal_equity  deal_valuation  \
# 85                    10.0            0.00101          4.0            0.03
#
#     amount_per_shark  equity_per_shark
# 85          0.000253               1.0

# %% [markdown]
# #Startup Ask Percentage : Min & Max

# %%
data[data["startup_ask_percentage"]==data["startup_ask_percentage"].max()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#     brand_name      description  deal_offered  startup_ask_percentage  \
# 30  Gopal's 56  Fiber Ice Cream             0                    25.0
#
#     deal_amount_lakhs  deal_equity  deal_valuation  amount_per_shark  \
# 30                0.0          0.0             0.0               0.0
#
#     equity_per_shark
# 30               0.0

# %%
data[data["startup_ask_percentage"]==data["startup_ask_percentage"].min()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#     brand_name              description  deal_offered  startup_ask_percentage  \
# 6  Qzense Labs  Food Freshness Detector             0                    0.25
#
#    deal_amount_lakhs  deal_equity  deal_valuation  amount_per_shark  \
# 6                0.0          0.0             0.0               0.0
#
#    equity_per_shark
# 6               0.0

# %% [markdown]
# #Startup Ask Valuation : Min & Max

# %%
data[data["startup_ask_valuation"]==data["startup_ask_valuation"].max()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#     brand_name      description  deal_offered  startup_ask_percentage  \
# 30  Gopal's 56  Fiber Ice Cream             0                    25.0
#
#     deal_amount_lakhs  deal_equity  deal_valuation  amount_per_shark  \
# 30                0.0          0.0             0.0               0.0
#
#     equity_per_shark
# 30               0.0

# %%
data[data["startup_ask_valuation"]==data["startup_ask_valuation"].min()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#             brand_name          description  deal_offered  \
# 85  Watt Technovations  Ventilated PPE Kits             1
#
#     startup_ask_percentage  deal_amount_lakhs  deal_equity  deal_valuation  \
# 85                    10.0            0.00101          4.0            0.03
#
#     amount_per_shark  equity_per_shark
# 85          0.000253               1.0

# %% [markdown]
# #Deal Amount : Min & Max

# %%
data[data["deal_amount_lakhs"]==data["deal_amount_lakhs"].max()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#        brand_name description  deal_offered  startup_ask_percentage  \
# 50  Aas Vidyalaya  EdTech App             1                     3.0
#
#     deal_amount_lakhs  deal_equity  deal_valuation  amount_per_shark  \
# 50              150.0         15.0          1000.0              50.0
#
#     equity_per_shark
# 50               5.0

# %%
data[data["deal_amount_lakhs"]==data["deal_amount_lakhs"].min()].head(1)[['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#        brand_name               description  deal_offered  \
# 4  Head and Heart  Brain Development Course             0
#
#    startup_ask_percentage  deal_amount_lakhs  deal_equity  deal_valuation  \
# 4                     5.0                0.0          0.0             0.0
#
#    amount_per_shark  equity_per_shark
# 4               0.0               0.0

# %% [markdown]
# #Deal Equity : Min & Max

# %%
data[data["deal_equity"]==data["deal_equity"].max()][['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#        brand_name description  deal_offered  startup_ask_percentage  \
# 65  Sid07 Designs  Inventions             1                    10.0
#
#     deal_amount_lakhs  deal_equity  deal_valuation  amount_per_shark  \
# 65               25.0         75.0           33.33              25.0
#
#     equity_per_shark
# 65              75.0

# %%
data[data["deal_equity"]==data["deal_equity"].min()].head(1)[['brand_name','description','deal_offered','startup_ask_percentage','deal_amount_lakhs','deal_equity','deal_valuation','amount_per_shark','equity_per_shark']]
# Out:
#        brand_name               description  deal_offered  \
# 4  Head and Heart  Brain Development Course             0
#
#    startup_ask_percentage  deal_amount_lakhs  deal_equity  deal_valuation  \
# 4                     5.0                0.0          0.0             0.0
#
#    amount_per_shark  equity_per_shark
# 4               0.0               0.0

# %% [markdown]
# ## Top 10 Brands Invested by Sharks

# %%
Shark_investment = data.groupby('brand_name')['deal_amount_lakhs'].sum()
top_10_Brands = Shark_investment.sort_values(ascending=False).head(10)
print("Top 10 Brands Invested by Sharks:")
print(top_10_Brands )
# Out:
# Top 10 Brands Invested by Sharks:
# brand_name
# Aas Vidyalaya          150.0
# Annie                  105.0
# Hammer Lifestyle       100.0
# Revamp Moto            100.0
# The Yarn Bazaar        100.0
# Sunfox Technologies    100.0
# Store My Goods         100.0
# Humpy A2               100.0
# IN A CAN               100.0
# Skippi Pops            100.0
# Name: deal_amount_lakhs, dtype: float64

# %% [markdown]
# ## Total Equity Buy and Amount Invested by Each Shark

# %%
#Aman
Equity = data.groupby('aman_invested')['equity_per_shark'].sum().loc[1]
Amount = data.groupby('aman_invested')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",Equity,'%')
print("Total amount invested on shark tank",Amount,"lakhs")
# Out:
# Total equity buy on shark tank 164.263333334 %
# Total amount invested on shark tank 894.500016693 lakhs

# %%
#Ashneer
Equity = data.groupby('ashneer_invested')['equity_per_shark'].sum().loc[1]
Amount = data.groupby('ashneer_invested')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",Equity,'%')
print("Total amount invested on shark tank",Amount,"lakhs")
# Out:
# Total equity buy on shark tank 93.249999999 %
# Total amount invested on shark tank 494.33333333 lakhs

# %%
#Ghazal
Equity = data.groupby('ghazal_invested')['equity_per_shark'].sum().loc[1]
Amount = data.groupby('ghazal_invested')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",Equity,'%')
print("Total amount invested on shark tank",Amount,"lakhs")
# Out:
# Total equity buy on shark tank 46.7 %
# Total amount invested on shark tank 130.00025250000002 lakhs

# %%
#Anupam
Equity = data.groupby('anupam_invested')['equity_per_shark'].sum().loc[1]
Amount = data.groupby('anupam_invested')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",Equity,'%')
print("Total amount invested on shark tank",Amount,"lakhs")
# Out:
# Total equity buy on shark tank 166.35 %
# Total amount invested on shark tank 533.83360253 lakhs

# %%
#Namita
Equity = data.groupby('namita_invested')['equity_per_shark'].sum().loc[1]
Amount = data.groupby('namita_invested')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",Equity,'%')
print("Total amount invested on shark tank",Amount,"lakhs")
# Out:
# Total equity buy on shark tank 140.783333334 %
# Total amount invested on shark tank 705.333602533 lakhs

# %%
#Peyush
Equity = data.groupby('peyush_invested')['equity_per_shark'].sum().loc[1]
Amount = data.groupby('peyush_invested')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",Equity,'%')
print("Total amount invested on shark tank",Amount,"lakhs")
# Out:
# Total equity buy on shark tank 317.85 %
# Total amount invested on shark tank 769.666919163 lakhs

# %%
#Vineeta
Equity = data.groupby('vineeta_invested')['equity_per_shark'].sum().loc[1]
Amount = data.groupby('vineeta_invested')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",Equity,'%')
print("Total amount invested on shark tank",Amount,"lakhs")
# Out:
# Total equity buy on shark tank 135.533333333 %
# Total amount invested on shark tank 335.33333333 lakhs

# %% [markdown]
# ## Sharks Invested in Companies

# %%
sharks = ['Anupam', 'Aman', 'Namita', 'Vineeta', 'Peyush', 'Ghazal', 'Ashneer']
for shark in sharks:
    total_deals = len(data[data[shark.lower() + '_invested'] == 1])
    print(shark, "deals with:", total_deals, "companies")
# Out:
# Anupam deals with: 24 companies
# Aman deals with: 29 companies
# Namita deals with: 24 companies
# Vineeta deals with: 16 companies
# Peyush deals with: 28 companies
# Ghazal deals with: 7 companies
# Ashneer deals with: 21 companies

# %%
total_aman_deals = len(data[data['aman_invested'] == 1])
print("Aman deals with:", total_aman_deals, "companies")
data[data["aman_invested"] == data["aman_invested"].max()][[ 'brand_name', 'description',
'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
# Out:
# Aman deals with: 29 companies
#                                             description  deal_amount_lakhs
# brand_name
# The Yarn Bazaar                        Yarn-Trading App          100.00000
# Revamp Moto                                      E-Bike          100.00000
# Skippi Pops                                    Ice-Pops          100.00000
# Raising Superstars                Child Development App          100.00000
# Get a Whey                          Sugar-Free Icecream          100.00000
# IN A CAN                                  Can Cocktails          100.00000
# Hammer Lifestyle                   Smart Audio Products          100.00000
# The Renal Project               Home Dialysis Treatment          100.00000
# Peeschute                          Disposable Urine Bag           75.00000
# AyuRythm                         Ayurvedic Wellness App           75.00000
# Beyond Water                      Liquid Water Enhancer           75.00000
# ...

# %%
total_anupam_deals = len(data[data['anupam_invested'] == 1])
print("Anupam deals with:", total_anupam_deals, "companies")
data[data["anupam_invested"] == data["anupam_invested"].max()][[ 'brand_name', 'description',
'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
# Out:
# Anupam deals with: 24 companies
#                                                        description  \
# brand_name
# Annie                                      Braille Literary Device
# Revamp Moto                                                 E-Bike
# Skippi Pops                                               Ice-Pops
# IN A CAN                                             Can Cocktails
# Sunfox Technologies                            Portable ECG Device
# The Yarn Bazaar                                   Yarn-Trading App
# Tweek Labs                                              Sportswear
# Hair Originals                             Natural Hair Extensions
# Vivalyf Innovations- Easy Life  Prickless Diabetes Testing Machine
# Cosiq                                         Intelligent Skincare
# Find Your Kicks India                               Sneaker Resale
# Bamboo India                                       Bamboo Products
# ...

# %%
total_ashneer_deals = len(data[data['ashneer_invested'] == 1])
print("Ashneer deals with:", total_ashneer_deals, "companies")
data[data["ashneer_invested"] == data["ashneer_invested"].max()][[ 'brand_name', 'description',
'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
# Out:
# Ashneer deals with: 21 companies
#                                                          description  \
# brand_name
# Aas Vidyalaya                                             EdTech App
# Skippi Pops                                                 Ice-Pops
# Raising Superstars                             Child Development App
# Get a Whey                                       Sugar-Free Icecream
# The Yarn Bazaar                                     Yarn-Trading App
# IN A CAN                                               Can Cocktails
# BluePine Industries                                     Frozen Momos
# Tagz Foods                                      Healthy Potato Chips
# Tweek Labs                                                Sportswear
# Hair Originals                               Natural Hair Extensions
# WeSTOCK                               Livestock health monitoring AI
# Find Your Kicks India                                 Sneaker Resale
# ...

# %%
total_ghazal_deals = len(data[data['ghazal_invested'] == 1])
print("Ghazal deals with:", total_ghazal_deals, "companies")
data[data["ghazal_invested"] == data["ghazal_invested"].max()][[ 'brand_name', 'description',
'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
# Out:
# Ghazal deals with: 7 companies
#                                     description  deal_amount_lakhs
# brand_name
# Sunfox Technologies         Portable ECG Device          100.00000
# Humpy A2                  Organic Milk Products          100.00000
# Wakao Foods                  Jackfruit Products           75.00000
# The Sass Bar                              Gifts           50.00000
# Gold Safe Solutions Ind.  Anti-Suicidal Fan Rod           50.00000
# Nomad Food Project                   Bacon Jams           40.00000
# Watt Technovations          Ventilated PPE Kits            0.00101

# %%
total_namita_deals = len(data[data['namita_invested'] == 1])
print("Namita deals with:", total_namita_deals, "companies")
data[data["namita_invested"] == data["namita_invested"].max()][[ 'brand_name', 'description',
'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
# Out:
# Namita deals with: 24 companies
#                                             description  deal_amount_lakhs
# brand_name
# Aas Vidyalaya                                EdTech App          150.00000
# Annie                           Braille Literary Device          105.00000
# Sunfox Technologies                 Portable ECG Device          100.00000
# IN A CAN                                  Can Cocktails          100.00000
# Skippi Pops                                    Ice-Pops          100.00000
# The Renal Project               Home Dialysis Treatment          100.00000
# Store My Goods                        Storage solutions          100.00000
# Kabaddi Adda                            All-Kabaddi App           80.00000
# Auli Lifestyle                       Ayurvedic Products           75.00000
# Wakao Foods                          Jackfruit Products           75.00000
# Bummer                                        Underwear           75.00000
# ...

# %%
total_peyush_deals = len(data[data['peyush_invested'] == 1])
print("Peyush deals with:", total_peyush_deals, "companies")
data[data["peyush_invested"] == data["peyush_invested"].max()][[ 'brand_name', 'description',
'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
# Out:
# Peyush deals with: 28 companies
#                                                         description  \
# brand_name
# Aas Vidyalaya                                            EdTech App
# Annie                                       Braille Literary Device
# Store My Goods                                    Storage solutions
# Humpy A2                                      Organic Milk Products
# Insurance Samadhan                              Insurance Solutions
# Sunfox Technologies                             Portable ECG Device
# The Yarn Bazaar                                    Yarn-Trading App
# IN A CAN                                              Can Cocktails
# RoadBounce                      Pothole Detection Software and Data
# Tweek Labs                                               Sportswear
# Hair Originals                              Natural Hair Extensions
# WeSTOCK                              Livestock health monitoring AI
# ...

# %%
total_vineeta_deals = len(data[data['vineeta_invested'] == 1])
print("Vineeta deals with:", total_vineeta_deals, "companies")
data[data["vineeta_invested"] == data["vineeta_invested"].max()][[ 'brand_name', 'description',
'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
# Out:
# Vineeta deals with: 16 companies
#                                                             description  \
# brand_name
# Skippi Pops                                                    Ice-Pops
# Get a Whey                                          Sugar-Free Icecream
# Sunfox Technologies                                 Portable ECG Device
# Humpy A2                                          Organic Milk Products
# Kabaddi Adda                                            All-Kabaddi App
# BluePine Industries                                        Frozen Momos
# Wakao Foods                                          Jackfruit Products
# Cosiq                                              Intelligent Skincare
# Gold Safe Solutions Ind.                          Anti-Suicidal Fan Rod
# Booz scooters             Renting e-bike for mobility in private spaces
# Nomad Food Project                                           Bacon Jams
# ...

# %% [markdown]
# # Data Visualization

# %%
Shark_investment = data.groupby('brand_name')['deal_amount_lakhs'].sum()
top_10_companies = Shark_investment.sort_values(ascending=False).head(10)
fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(top_10_companies.index, top_10_companies.values,color='black')
ax.set_xlabel('Brands')
ax.set_ylabel('Total Investment (in Lakhs)')
ax.set_title('Top 10 Brands Invested by Sharks',size=15,color='black')
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %%
sharks = ['Anupam', 'Aman', 'Namita', 'Vineeta', 'Peyush', 'Ghazal', 'Ashneer']
total_deals = []

for shark in sharks:
    deals = len(data[data[shark.lower() + '_invested'] == 1])
    total_deals.append(deals)
   # Sorting sharks and total_deals in descending order
sorted_sharks, sorted_deals = zip(*sorted(zip(sharks, total_deals), key=lambda x: x[1], reverse=False))

fig, ax = plt.subplots(figsize=(7, 4))
ax.barh(sorted_sharks, sorted_deals,color='black')
for i, v in enumerate(sorted_deals):
    ax.text(v + 0.5, i, str(v), color='black', fontweight='bold')
ax.set_xlabel('Total Companies')
ax.set_ylabel('Shark')
ax.set_title('Companies Invested by Each Shark',size=15,color='black')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(total_deals, labels=sharks, autopct='%1.1f%%', startangle=90)
ax.set_title('Sharks Investment by Percentage',size=15,color='black')
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.show()

# %%
total_aman_deals = len(data[data['aman_invested'] == 1])
aman_max_investments = data[data["aman_invested"] == data["aman_invested"].max()][['brand_name', 'description', 'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
plt.figure(figsize=(10, 3))
ax = plt.gca()
ax.bar(aman_max_investments.index, aman_max_investments['deal_amount_lakhs'], color='orange')
ax.set_xlabel('Brand Name')
ax.set_ylabel('Deal Amount (in Lakhs)')
ax.set_title("Aman's Deals",size=15,color='black')
ax.set_facecolor('lightgray')
plt.xticks(rotation=90)
for i, value in enumerate(aman_max_investments['deal_amount_lakhs']):
    ax.text(i, value/2, str(value), ha='center', va='center', fontsize=8, rotation='vertical', color='black')
plt.show()

# %%
total_anupam_deals = len(data[data['anupam_invested'] == 1])
anupam_max_investments = data[data["anupam_invested"] == data["anupam_invested"].max()][['brand_name', 'description', 'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
plt.figure(figsize=(10, 3))
ax = plt.gca()
ax.bar(anupam_max_investments.index, anupam_max_investments['deal_amount_lakhs'], color='blue')
ax.set_xlabel('Brand Name')
ax.set_ylabel('Deal Amount (in Lakhs)')
ax.set_title("Anupam's Deals",size=15,color='black')
ax.set_facecolor('lightgray')
plt.xticks(rotation=90)
for i, value in enumerate(anupam_max_investments['deal_amount_lakhs']):
    ax.text(i, value/2, str(value), ha='center', va='center', fontsize=8, rotation='vertical', color='black')
plt.show()

# %%
total_ashneer_deals = len(data[data['ashneer_invested'] == 1])
ashneer_max_investments = data[data["ashneer_invested"] == data["ashneer_invested"].max()][['brand_name', 'description', 'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
plt.figure(figsize=(10, 3))
ax = plt.gca()
ax.bar(ashneer_max_investments.index, ashneer_max_investments['deal_amount_lakhs'], color='pink')
ax.set_xlabel('Brand Name')
ax.set_ylabel('Deal Amount (in Lakhs)')
ax.set_title("Ashneer's Deals",size=15,color='black')
ax.set_facecolor('lightgray')
plt.xticks(rotation=90)
for i, value in enumerate(ashneer_max_investments['deal_amount_lakhs']):
    ax.text(i, value/2, str(value), ha='center', va='center', fontsize=8, rotation='vertical', color='black')
plt.show()

# %%
total_ghazal_deals = len(data[data['ghazal_invested'] == 1])
ghazal_max_investments = data[data["ghazal_invested"] == data["ghazal_invested"].max()][['brand_name', 'description', 'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
plt.figure(figsize=(10, 3))
ax = plt.gca()
ax.bar(ghazal_max_investments.index, ghazal_max_investments['deal_amount_lakhs'], color='brown')
ax.set_xlabel('Brand Name')
ax.set_ylabel('Deal Amount (in Lakhs)')
ax.set_title("Ghazal's Deals",size=15,color='black')
ax.set_facecolor('lightgray')
plt.xticks(rotation=90)
for i, value in enumerate(ghazal_max_investments['deal_amount_lakhs']):
    ax.text(i, value/2, str(value), ha='center', va='center', fontsize=8, rotation='vertical', color='black')
plt.show()

# %%
total_namita_deals = len(data[data['namita_invested'] == 1])
namita_max_investments = data[data["namita_invested"] == data["namita_invested"].max()][['brand_name', 'description', 'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
plt.figure(figsize=(10, 3))
ax = plt.gca()
ax.bar(namita_max_investments.index, namita_max_investments['deal_amount_lakhs'], color='green')
ax.set_xlabel('Brand Name')
ax.set_ylabel('Deal Amount (in Lakhs)')
ax.set_title("Namita's Deals",size=15,color='black')
ax.set_facecolor('lightgray')
plt.xticks(rotation=90)
for i, value in enumerate(namita_max_investments['deal_amount_lakhs']):
    ax.text(i, value/2, str(value), ha='center', va='center', fontsize=8, rotation='vertical', color='black')
plt.show()

# %%
total_peyush_deals = len(data[data['peyush_invested'] == 1])
peyush_max_investments = data[data["peyush_invested"] == data["peyush_invested"].max()][['brand_name', 'description', 'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
plt.figure(figsize=(10, 3))
ax = plt.gca()
ax.bar(peyush_max_investments.index, peyush_max_investments['deal_amount_lakhs'], color='purple')
ax.set_xlabel('Brand Name')
ax.set_ylabel('Deal Amount (in Lakhs)')
ax.set_title("Peyush's Deals",size=15,color='black')
ax.set_facecolor('lightgray')
plt.xticks(rotation=90)
for i, value in enumerate(peyush_max_investments['deal_amount_lakhs']):
    ax.text(i, value/2, str(value), ha='center', va='center', fontsize=8, rotation='vertical', color='black')
plt.show()

# %%
total_vineeta_deals = len(data[data['vineeta_invested'] == 1])
vineeta_max_investments = data[data["vineeta_invested"] == data["vineeta_invested"].max()][['brand_name', 'description', 'deal_amount_lakhs']].set_index('brand_name').sort_values(by='deal_amount_lakhs', ascending=False)
plt.figure(figsize=(10, 3))
ax = plt.gca()
ax.bar(vineeta_max_investments.index, vineeta_max_investments['deal_amount_lakhs'], color='red')
ax.set_xlabel('Brand Name')
ax.set_ylabel('Deal Amount (in Lakhs)')
ax.set_title("Vineeta's Deals",size=15,color='black')
ax.set_facecolor('lightgray')
plt.xticks(rotation=90)
for i, value in enumerate(vineeta_max_investments['deal_amount_lakhs']):
    ax.text(i, value/2, str(value), ha='center', va='center', fontsize=8, rotation='vertical', color='black')
plt.show()

# %%
from wordcloud import WordCloud
text_data = ' '.join(data['brand_name'])
wordcloud = WordCloud().generate(text_data)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
