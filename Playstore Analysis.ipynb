# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
Data=pd.read_csv("googleplaystore.csv")
Data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
Data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
Data.shape
# Out:
# (10841, 13)

# %%
Data.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # Data Cleaning and Preparation

# %%
Data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
sns.heatmap(Data.isnull())

# %%
Data.drop(['Genres','Last Updated','Current Ver',"Android Ver"],axis=1,inplace=True)

# %%
Data["Rating"]=Data["Rating"].fillna(0)
Data["Type"]=Data["Type"].fillna(0)

# %%
sns.heatmap(Data.isnull())

# %%
Data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating'],
#       dtype='object')

# %% [markdown]
# # Apps Category

# %%
#Finding value count of each category for the apps

# %%
Data.Category.value_counts(ascending=False)
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.title("App Category With Count",size=15,color='black')
sns.set_style(style="darkgrid")
ax = sns.countplot(x="Category", data=Data)

# %%
Data.Category.value_counts(ascending=False).nlargest(10).sort_values(ascending=False).plot.bar()
plt.xlabel("Category",size=15,color='black')
plt.ylabel("Number of Apps",size=15,color='black')
plt.title("Top10 categories with value count of app",size=20,color='black')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Apps With  Rating

# %%
Data['Rating'].max()
# Out:
# 19.0

# %%
Data[Data.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating
# 10472  1,000+     Free    0  Everyone            NaN

# %%
Data.drop([10472],inplace=True)

# %%
Top10_App=Data.nlargest(10,"Rating")[["Rating","App"]]
Top10_App
# Out:
#       Rating                                         App
# 329      5.0                Hojiboy Tojiboyev Life Hacks
# 612      5.0               American Girls Mobile Numbers
# 615      5.0                                Awake Dating
# 633      5.0                       Spine- The dating app
# 636      5.0  Girls Live Talk - Free Text and Video Chat
# 640      5.0                     Online Girls Chat Group
# 654      5.0             Speeding Joyride & Car Meet App
# 1028     5.0                            SUMMER SONIC app
# 1030     5.0                                  Prosperity
# 1038     5.0                   Mindvalley U Tallinn 2018

# %%
Top10_App.set_index("Rating")
# Out:
#                                                App
# Rating
# 5.0                   Hojiboy Tojiboyev Life Hacks
# 5.0                  American Girls Mobile Numbers
# 5.0                                   Awake Dating
# 5.0                          Spine- The dating app
# 5.0     Girls Live Talk - Free Text and Video Chat
# 5.0                        Online Girls Chat Group
# 5.0                Speeding Joyride & Car Meet App
# 5.0                               SUMMER SONIC app
# 5.0                                     Prosperity
# 5.0                      Mindvalley U Tallinn 2018

# %%
sns.barplot(x="Rating",y="App",data=Top10_App)
plt.title("The Top10 Apps of the Playstore Which Have Max Rating",size=15,color='black')
plt.show()

# %%
#count of rating 
Rating_Count=Data.Rating.value_counts()

# %%
Data.Rating.value_counts()
# Out:
# 0.0    1474
# 4.4    1109
# 4.3    1076
# 4.5    1038
# 4.2     952
# 4.6     823
# 4.1     708
# 4.0     568
# 4.7     499
# 3.9     386
# 3.8     303
# 5.0     274
# 3.7     239
# 4.8     234
# 3.6     174
# 3.5     163
# 3.4     128
# 3.3     102
# 4.9      87
# 3.0      83
# 3.1      69
# 3.2      64
# 2.9      45
# 2.8      42
# 2.7      25
# 2.6      25
# 2.5      21
# 2.3      20
# 2.4      19
# 1.0      16
# 2.2      14
# 1.9      13
# 2.0      12
# 1.7       8
# 1.8       8
# 2.1       8
# 1.6       4
# 1.5       3
# 1.4       3
# 1.2       1
# Name: Rating, dtype: int64

# %%
# Count plot With rating
plt.figure(figsize=(15,5))
plt.xticks(rotation=45)
plt.title("App Count with Rating",size=15,color='black')
ax = sns.countplot(x="Rating", data=Data)

# %%
Data["Rating"].value_counts().head(10).sort_values(ascending=True).plot.bar()
plt.xlabel("Rating",size=15,color='black')
plt.ylabel("Number of Apps",size=15,color='black')
plt.title("Top 10 Playstore App Rating with count",size=20,color='black')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Apps With Review

# %%
Data.sort_values(by="Reviews", ascending= False)
# Out:
#                                     App      Category  Rating Reviews  Size  \
# 2989             GollerCepte Live Score        SPORTS     4.2    9992   31M
# 4970       Ad Block REMOVER - NEED ROOT         TOOLS     3.3     999   91k
# 2723                SnipSnap Coupon App      SHOPPING     4.2    9975   18M
# 2705                SnipSnap Coupon App      SHOPPING     4.2    9975   18M
# 3079  US Open Tennis Championships 2018        SPORTS     4.0    9971   33M
# ...                                 ...           ...     ...     ...   ...
# 2465                  ear super hearing       MEDICAL     0.0       0  1.4M
# 9925                      Reisedealz.eu        SOCIAL     0.0       0   10M
# 9928                        EU Whoiswho      BUSINESS     0.0       0  2.7M
# 9929     EU Brazil Green Business Forum  PRODUCTIVITY     0.0       0  8.7M
# 7101                 Register.ca Mobile  PRODUCTIVITY     0.0       0  1.2M
#
#         Installs  Type Price Content Rating
# ...

# %%
#Top apps sorted by reviews
Top10_Review=Data.sort_values(by="Reviews", ascending= False).head(10)
Top10_Review
# Out:
#                                                     App          Category  \
# 2989                             GollerCepte Live Score            SPORTS
# 4970                       Ad Block REMOVER - NEED ROOT             TOOLS
# 2723                                SnipSnap Coupon App          SHOPPING
# 2705                                SnipSnap Coupon App          SHOPPING
# 3079                  US Open Tennis Championships 2018            SPORTS
# 3229                                         DreamTrips  TRAVEL_AND_LOCAL
# 3049                  US Open Tennis Championships 2018            SPORTS
# 7002   Adult Color by Number Book - Paint Mandala Pages            FAMILY
# 6724                     BSPlayer ARMv7 VFP CPU support     VIDEO_PLAYERS
# 7982  Easy Resume Builder, Resume help, Curriculum v...             TOOLS
#
#       Rating Reviews                Size    Installs  Type Price  \
# 2989     4.2    9992                 31M  1,000,000+  Free     0
# ...

# %%
Data.Reviews= Data["Reviews"].str.replace("M", "")

# %%
Data.Reviews= Data["Reviews"].str.replace("M", "")

# %%
Data.Reviews= Data.Reviews.astype(float)

# %%
Top10=Data.nlargest(10,"Reviews")[["Reviews","App"]]
Top10
Top10.set_index("App")
# Out:
#                                              Reviews
# App
# Facebook                                  78158306.0
# Facebook                                  78128208.0
# WhatsApp Messenger                        69119316.0
# WhatsApp Messenger                        69119316.0
# WhatsApp Messenger                        69109672.0
# Instagram                                 66577446.0
# Instagram                                 66577313.0
# Instagram                                 66577313.0
# Instagram                                 66509917.0
# Messenger – Text and Video Chat for Free  56646578.0

# %%
Index=Top10.set_index("App")
Index
# Out:
#                                              Reviews
# App
# Facebook                                  78158306.0
# Facebook                                  78128208.0
# WhatsApp Messenger                        69119316.0
# WhatsApp Messenger                        69119316.0
# WhatsApp Messenger                        69109672.0
# Instagram                                 66577446.0
# Instagram                                 66577313.0
# Instagram                                 66577313.0
# Instagram                                 66509917.0
# Messenger – Text and Video Chat for Free  56646578.0

# %%
plt.figure(figsize=(7,3))
sns.barplot(x="Reviews",y='App',data=Top10)
plt.title("Apps Who Has Max Rating",size=15,color='black')
plt.show()

# %% [markdown]
# # Apps With Type

# %%
#Free and Paid Apps

# %%
Data["Type"].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
Data["Type"].value_counts().plot.bar()
plt.xlabel("Type",size=15,color='black')
plt.ylabel("Count",size=15,color='black')
plt.title("Apps - Free and Paid",size=20,color='black')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Apps With Size

# %%
Data.Size.unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
Size_Count=Data.Size.value_counts()
Size_Count
# Out:
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 695k                     1
# 613k                     1
# 454k                     1
# 840k                     1
# 811k                     1
# Name: Size, Length: 461, dtype: int64

# %%
Max_Size=Data.sort_values(by="Size", ascending= False)
Max_Size
# Out:
#                                 App            Category  Rating    Reviews  \
# 3675                VLC for Android       VIDEO_PLAYERS     4.4  1032076.0
# 9575     Red Hands – 2-Player Games                GAME     4.2    93608.0
# 5779   AW - Le News di AndroidWorld  NEWS_AND_MAGAZINES     4.1     2808.0
# 5778        ByssWeather for Wear OS             WEATHER     4.2    19666.0
# 5773                Bits Watch Face        PRODUCTIVITY     4.0     6205.0
# ...                             ...                 ...     ...        ...
# 7074            WISE- MOBILE PORTAL               TOOLS     0.0        3.0
# 8077                         go41cx              FAMILY     4.8      171.0
# 10043          Remote EX for NISSAN       COMMUNICATION     2.3      223.0
# 9973      German Vocabulary Trainer              FAMILY     3.3     1218.0
# 5771                        News.aw  NEWS_AND_MAGAZINES     0.0        1.0
#
#                      Size      Installs  Type   Price Content Rating
# ...

# %%
Min_Size=Data.sort_values(by="Size", ascending=True)
Min_Size
# Out:
#                                                App            Category  \
# 7074                           WISE- MOBILE PORTAL               TOOLS
# 6446                          BL PowerPoint Remote               TOOLS
# 10043                         Remote EX for NISSAN       COMMUNICATION
# 9973                     German Vocabulary Trainer              FAMILY
# 8077                                        go41cx              FAMILY
# ...                                            ...                 ...
# 1333                Relax with Andrew Johnson Lite  HEALTH_AND_FITNESS
# 1327                                   Pocket Yoga  HEALTH_AND_FITNESS
# 1325   Seven - 7 Minute Workout Training Challenge  HEALTH_AND_FITNESS
# 5952                             American Airlines    TRAVEL_AND_LOCAL
# 2076                                  Happy Street              FAMILY
#
#        Rating   Reviews                Size    Installs  Type   Price  \
# ...

# %%
Data.Size= Data["Size"].str.replace("Varies with device", "")

# %%
#Top10 apps Have Max Size

# %%
Max_Size=Data.sort_values(by="Size", ascending= False).head(10)[["Size","App"]]
Max_Size
Max_Size.set_index('Size')
# Out:
#                                     App
# Size
# 99M   L.A. Crime Stories Mad City Crime
# 99M                    Chakra Cleansing
# 99M      Angry Birds POP Bubble Shooter
# 99M                       Gangster Town
# 99M                          music (CG)
# 99M                         Rope Hero 3
# 99M                        AI Benchmark
# 99M                   Angry Birds Blast
# 99M                   My Talking Angela
# 99M                       Earn to Die 2

# %% [markdown]
# # Apps With Installed

# %%
Data.sort_values(by="Installs", ascending= False).head()
# Out:
#                                         App       Category  Rating  \
# 1661                           Temple Run 2           GAME     4.3
# 4039  Google Duo - High Quality Video Calls  COMMUNICATION     4.6
# 385                         Viber Messenger  COMMUNICATION     4.3
# 3562                        Google Calendar   PRODUCTIVITY     4.2
# 4048                                Dropbox   PRODUCTIVITY     4.4
#
#          Reviews Size      Installs  Type Price Content Rating
# 1661   8118609.0  62M  500,000,000+  Free     0       Everyone
# 4039   2083237.0       500,000,000+  Free     0       Everyone
# 385   11334973.0       500,000,000+  Free     0       Everyone
# 3562    858230.0       500,000,000+  Free     0       Everyone
# 4048   1860844.0  61M  500,000,000+  Free     0       Everyone

# %%
Data.Installs= Data["Installs"].replace("+", "")

# %%
Data.Installs= Data["Installs"].replace(",", "")

# %%
Data.Installs= Data["Installs"].replace("Free", "")

# %%
Data.sort_values(by="Installs", ascending= False).head()
# Out:
#                                         App       Category  Rating  \
# 1661                           Temple Run 2           GAME     4.3
# 4039  Google Duo - High Quality Video Calls  COMMUNICATION     4.6
# 385                         Viber Messenger  COMMUNICATION     4.3
# 3562                        Google Calendar   PRODUCTIVITY     4.2
# 4048                                Dropbox   PRODUCTIVITY     4.4
#
#          Reviews Size      Installs  Type Price Content Rating
# 1661   8118609.0  62M  500,000,000+  Free     0       Everyone
# 4039   2083237.0       500,000,000+  Free     0       Everyone
# 385   11334973.0       500,000,000+  Free     0       Everyone
# 3562    858230.0       500,000,000+  Free     0       Everyone
# 4048   1860844.0  61M  500,000,000+  Free     0       Everyone

# %%
#Top10 Installed apps

# %%
top_installed_apps = Data.sort_values(by=["Installs"], ascending=False)[["Installs","App"]]
top_installed_apps.set_index("App").head(10)
# Out:
#                                            Installs
# App
# Temple Run 2                           500,000,000+
# Google Duo - High Quality Video Calls  500,000,000+
# Viber Messenger                        500,000,000+
# Google Calendar                        500,000,000+
# Dropbox                                500,000,000+
# Dropbox                                500,000,000+
# Temple Run 2                           500,000,000+
# LINE: Free Calls & Messages            500,000,000+
# Cloud Print                            500,000,000+
# Flipboard: News For Our Time           500,000,000+
